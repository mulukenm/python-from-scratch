# %%
from bs4 import BeautifulSoup
import requests
# import libraries
import urllib.request
import csv

# %%
# from selenium import webdriver

# DRIVER_PATH = '/path/to/chromedriver'
# driver = webdriver.Chrome(executable_path=DRIVER_PATH)
# driver.get('https://google.com')

# %%
# from selenium import webdriver
# from selenium.webdriver.chrome.options import Options

# options = Options()
# options.headless = True
# options.add_argument("--window-size=1920,1200")

# driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)
# driver.get("https://www.nintendo.com/")
# print(driver.page_source)
# driver.quit()

# %%
import requests
from bs4 import BeautifulSoup
 
 
url = 'https://scholar.google.com/scholar?hl=en&as_sdt=0%2C47&q=NCSES&oq='
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')
 
urls = []
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# /schhp?hl=en&oe=ASCII&as_sdt=0,47
# /scholar?as_sdt=0,47&q=NCSES&hl=en&oe=ASCII
# /scholar?as_sdt=6,47&q=NCSES&hl=en&oe=ASCII
# /citations?view_op=search_authors&mauthors=NCSES&hl=en&oe=ASCII&oi=drw
# /citations?hl=en&oe=ASCII
# /scholar?scilib=1&scioq=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar_alerts?view_op=list_alerts&hl=en&oe=ASCII
# /citations?view_op=top_venues&hl=en&oe=ASCII
# javascript:void(0)
# /scholar_settings?q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# https://accounts.google.com/Login?hl=en&continue=https://scholar.google.com/scholar%3Fhl%3Den%26as_sdt%3D0%252C47%26q%3DNCSES%26oq%3D
# javascript:void(0)
# /schhp?hl=en&oe=ASCII&as_sdt=0,47
# https://accounts.google.com/Login?hl=en&continue=https://scholar.google.com/scholar%3Fhl%3Den%26as_sdt%3D0%252C47%26q%3DNCSES%26oq%3D
# javascript:void(0)
# /citations?hl=en&oe=ASCII
# /scholar?scilib=1&scioq=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?as_ylo=2021&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?as_ylo=2020&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?as_ylo=2017&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&q=NCSES
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&q=NCSES&scisbd=1
# /scholar?as_sdt=1,47&q=NCSES&hl=en&oe=ASCII
# /scholar?as_vis=1&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?as_ylo=2021&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?as_ylo=2020&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?as_ylo=2017&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# javascript:void(0)
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&q=NCSES
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&q=NCSES&scisbd=1
# /scholar?as_sdt=1,47&q=NCSES&hl=en&oe=ASCII
# /scholar?as_vis=1&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar_alerts?view_op=create_alert_options&hl=en&alert_query=NCSES&alert_params=%3Fhl%3Den%26as_sdt%3D0,47
# https://sites.nationalacademies.org/cs/groups/pgasite/documents/webpage/pga_178246.pdf
# https://sites.nationalacademies.org/cs/groups/pgasite/documents/webpage/pga_178246.pdf
# javascript:void(0)
# javascript:void(0)
# /scholar?cites=2163168439743310502&as_sdt=5,47&sciodt=0,47&hl=en&oe=ASCII
# /scholar?q=related:pmo8KDweBR4J:scholar.google.com/&scioq=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?cluster=2163168439743310502&hl=en&oe=ASCII&as_sdt=0,47
# javascript:void(0)
# https://scholar.googleusercontent.com/scholar?q=cache:pmo8KDweBR4J:scholar.google.com/+NCSES&hl=en&oe=ASCII&as_sdt=0,47
# javascript:void(0)
# https://www.sciencedirect.com/science/article/pii/S1059131114002581
# https://www.sciencedirect.com/science/article/pii/S1059131114002581
# /citations?user=iDAfdmkAAAAJ&hl=en&oe=ASCII&oi=sra
# javascript:void(0)
# javascript:void(0)
# /scholar?cites=8124879778509057917&as_sdt=5,47&sciodt=0,47&hl=en&oe=ASCII
# /scholar?q=related:fW_JcBxfwXAJ:scholar.google.com/&scioq=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?cluster=8124879778509057917&hl=en&oe=ASCII&as_sdt=0,47
# javascript:void(0)
# javascript:void(0)
# https://books.google.com/books?hl=en&lr=&id=f4LWBAAAQBAJ&oi=fnd&pg=PT24&dq=NCSES&ots=O2x7Lnefm5&sig=iOSBed1lZXxzF1S6Zi3PPOmRpk8
# javascript:void(0)
# javascript:void(0)
# /scholar?cites=12595204615355752987&as_sdt=5,47&sciodt=0,47&hl=en&oe=ASCII
# /scholar?q=related:G-Kji90ny64J:scholar.google.com/&scioq=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# javascript:void(0)
# /scholar?output=instlink&q=info:G-Kji90ny64J:scholar.google.com/&hl=en&oe=ASCII&as_sdt=0,47&scillfp=5416281587225728830&oi=llo
# javascript:void(0)
# https://www.emerald.com/insight/content/doi/10.1108/09504121111156201/full/html
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# https://mediatum.ub.tum.de/doc/1439792/file.pdf
# https://ieeexplore.ieee.org/abstract/document/8429495/
# /citations?user=Pp50-6AAAAAJ&hl=en&oe=ASCII&oi=sra
# javascript:void(0)
# javascript:void(0)
# /scholar?cites=236742763767833585&as_sdt=5,47&sciodt=0,47&hl=en&oe=ASCII
# /scholar?q=related:8aOGEUoUSQMJ:scholar.google.com/&scioq=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?cluster=236742763767833585&hl=en&oe=ASCII&as_sdt=0,47
# javascript:void(0)
# javascript:void(0)
# https://www.healio.com/nursing/journals/jne/2015-10-54-10/%7Bc4e6adaf-66e9-45e2-8796-58a002ee5948%7D/development-and-psychometric-assessment-of-the-nursing-competence-self-efficacy-scale
# /citations?user=lB7dl1wAAAAJ&hl=en&oe=ASCII&oi=sra
# javascript:void(0)
# javascript:void(0)
# /scholar?cites=4317580717842480098&as_sdt=5,47&sciodt=0,47&hl=en&oe=ASCII
# /scholar?q=related:4rsTkMkg6zsJ:scholar.google.com/&scioq=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?cluster=4317580717842480098&hl=en&oe=ASCII&as_sdt=0,47
# javascript:void(0)
# javascript:void(0)
# https://tpcjournal.nbcc.org/wp-content/uploads/2020/12/Pages-532-547-Kent-Mentoring-Doctoral-Student-Mothers-in-Counselor-Education.pdf
# https://tpcjournal.nbcc.org/wp-content/uploads/2020/12/Pages-532-547-Kent-Mentoring-Doctoral-Student-Mothers-in-Counselor-Education.pdf
# /citations?user=2kEm2OAAAAAJ&hl=en&oe=ASCII&oi=sra
# javascript:void(0)
# javascript:void(0)
# /scholar?cites=15689763111241605851&as_sdt=5,47&sciodt=0,47&hl=en&oe=ASCII
# /scholar?q=related:22KV92s8vdkJ:scholar.google.com/&scioq=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?cluster=15689763111241605851&hl=en&oe=ASCII&as_sdt=0,47
# javascript:void(0)
# https://scholar.googleusercontent.com/scholar?q=cache:22KV92s8vdkJ:scholar.google.com/+NCSES&hl=en&oe=ASCII&as_sdt=0,47
# javascript:void(0)
# https://www.jaad.org/article/S0190-9622(14)01476-5/fulltext
# https://www.jaad.org/article/S0190-9622(14)01476-5/abstract
# javascript:void(0)
# javascript:void(0)
# /scholar?cites=1166796523137628938&as_sdt=5,47&sciodt=0,47&hl=en&oe=ASCII
# /scholar?q=related:CnvHfkFLMRAJ:scholar.google.com/&scioq=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?cluster=1166796523137628938&hl=en&oe=ASCII&as_sdt=0,47
# javascript:void(0)
# javascript:void(0)
# https://ecommons.cornell.edu/bitstream/handle/1813/36394/NCRN-Spring2014-SessionI-Mulcahy.pdf;sequence=2
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# https://scholar.googleusercontent.com/scholar?q=cache:DCm2q9InWe4J:scholar.google.com/+NCSES&hl=en&oe=ASCII&as_sdt=0,47
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# /scholar?cites=8496855478118254172&as_sdt=5,47&sciodt=0,47&hl=en&oe=ASCII
# /scholar?q=related:XAYSAQrl6nUJ:scholar.google.com/&scioq=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# javascript:void(0)
# javascript:void(0)
# /scholar_alerts?view_op=create_alert_options&hl=en&alert_query=NCSES&alert_params=%3Fhl%3Den%26as_sdt%3D0,47
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&qsp=1&q=engineering+statistics+ncses&qst=bb
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&qsp=2&q=ncses+self+efficacy+scale&qst=bb
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&qsp=3&q=ncses+science+and+engineering&qst=bb
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&qsp=4&q=ncses+survey&qst=bb
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&qsp=5&q=ncses+national+center&qst=bb
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&qsp=6&q=ncses+center+for+science&qst=bb
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&qsp=7&q=ncses+national+science+foundation&qst=bb
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&qsp=8&q=ncses+nursing+competence&qst=bb
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&qsp=9&q=ncses+r%26d&qst=bb
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&qsp=10&q=ncses+minorities&qst=bb
# /scholar?hl=en&oe=ASCII&as_sdt=0,47&qsp=11&q=ncses+competence+self+efficacy&qst=bb
# /scholar?start=10&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=20&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=30&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=40&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=50&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=60&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=70&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=80&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=90&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=10&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=10&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=20&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=30&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=40&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=50&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=60&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=70&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=80&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /scholar?start=90&q=NCSES&hl=en&oe=ASCII&as_sdt=0,47
# /intl/en/scholar/about.html
# //www.google.com/intl/en/policies/privacy/
# //www.google.com/intl/en/policies/terms/

# %%
page = requests.get("https://codedamn.com")
soup = BeautifulSoup(page.content, 'html.parser')
title = soup.title.text # gets you the text of the <title>(...)</title>

# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in c:\users\muluken\anaconda3\lib\site-packages (from selenium) (1.26.2)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# Note: you may need to restart the kernel to use updated packages.
